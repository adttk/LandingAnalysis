# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'User_Interface.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1004, 573)
        self.tabPreparation = QtWidgets.QTabWidget(Form)
        self.tabPreparation.setGeometry(QtCore.QRect(0, 0, 1001, 561))
        self.tabPreparation.setStyleSheet("background-color: rgba(217, 211, 244, 1);\n"
"")
        self.tabPreparation.setStyleSheet("QToolButton { border-width: 1px; border-style: solid; border-color: green; background-color: red;}");
        self.tabPreparation.setTabPosition(QtWidgets.QTabWidget.North)
        self.tabPreparation.setTabShape(QtWidgets.QTabWidget.Rounded)
        self.tabPreparation.setElideMode(QtCore.Qt.ElideNone)
        self.tabPreparation.setTabBarAutoHide(False)
        self.tabPreparation.setObjectName("tabPreparation")
        self.tab = QtWidgets.QWidget()
        self.tab.setStyleSheet("")
        self.tab.setObjectName("tab")
        self.textPreparation = QtWidgets.QTextBrowser(self.tab)
        self.textPreparation.setGeometry(QtCore.QRect(830, 70, 141, 431))
        font = QtGui.QFont()
        font.setFamily("MS Shell Dlg 2")
        font.setPointSize(8)
        font.setBold(False)
        font.setItalic(False)
        font.setWeight(50)
        self.textPreparation.setFont(font)
        self.textPreparation.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 8pt \"MS Shell Dlg 2\";\n"
"border-radius:5px;")
        self.textPreparation.setFrameShadow(QtWidgets.QFrame.Raised)
        self.textPreparation.setObjectName("textPreparation")
        self.tableViewPreparation = QtWidgets.QTableView(self.tab)
        self.tableViewPreparation.setGeometry(QtCore.QRect(30, 70, 771, 431))
        self.tableViewPreparation.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 8pt \"MS Shell Dlg 2\";\n"
"border-radius:5px;")
        self.tableViewPreparation.setFrameShape(QtWidgets.QFrame.StyledPanel)
        self.tableViewPreparation.setObjectName("tableViewPreparation")
        self.PathLinePrepare = QtWidgets.QLineEdit(self.tab)
        self.PathLinePrepare.setGeometry(QtCore.QRect(160, 20, 511, 22))
        self.PathLinePrepare.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 8pt \"MS Shell Dlg 2\";\n"
"border-radius:5px;")
        self.PathLinePrepare.setObjectName("PathLinePrepare")
        self.CheckDataButton = QtWidgets.QPushButton(self.tab)
        self.CheckDataButton.setGeometry(QtCore.QRect(855, 20, 120, 26))
        self.CheckDataButton.setStyleSheet("background-color: rgba(117, 123, 157, 1);\n"
"color: rgb(255, 255, 255);\n"
"font: 650 9pt \"Segoe UI Semibold\";\n"
"border-radius:1.5px;\n"
"border-style:solid;\n"
"border-bottom-width:4px;\n"
"border-right-widt:3px;\n"
"border-right-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:1,  stop:0 rgba(117, 123, 157,1), stop:1 rgba(217, 221, 244, 1));\n"
"border-bottom-color: qlineargradient(spread:pad, x1:0.301136, y1:0.034, x2:0.301, y2:1, stop:0 rgba(117, 123, 157, 1), stop:1 rgba(217, 221, 244, 1));\n"
"")
        self.CheckDataButton.setObjectName("CheckDataButton")
        self.PreparationButton = QtWidgets.QPushButton(self.tab)
        self.PreparationButton.setGeometry(QtCore.QRect(690, 20, 134, 26))
        self.PreparationButton.setStyleSheet("background-color: rgba(117, 123, 157, 1);\n"
"color: rgb(255, 255, 255);\n"
"font: 650 9pt \"Segoe UI Semibold\";\n"
"border-radius:1.5px;\n"
"border-style:solid;\n"
"border-bottom-width:4px;\n"
"border-right-widt:3px;\n"
"border-right-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:1,  stop:0 rgba(117, 123, 157,1), stop:1 rgba(217, 221, 244, 1));\n"
"border-bottom-color: qlineargradient(spread:pad, x1:0.301136, y1:0.034, x2:0.301, y2:1, stop:0 rgba(117, 123, 157, 1), stop:1 rgba(217, 221, 244, 1));\n"
"")
        self.PreparationButton.setObjectName("PreparationButton")
        self.browseRawData = QtWidgets.QPushButton(self.tab)
        self.browseRawData.setGeometry(QtCore.QRect(10, 20, 134, 26))
        palette = QtGui.QPalette()
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.WindowText, brush)
        brush = QtGui.QBrush(QtGui.QColor(117, 123, 157))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Button, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Text, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.ButtonText, brush)
        brush = QtGui.QBrush(QtGui.QColor(117, 123, 157))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Base, brush)
        brush = QtGui.QBrush(QtGui.QColor(117, 123, 157))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Active, QtGui.QPalette.Window, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.WindowText, brush)
        brush = QtGui.QBrush(QtGui.QColor(117, 123, 157))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Button, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Text, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.ButtonText, brush)
        brush = QtGui.QBrush(QtGui.QColor(117, 123, 157))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Base, brush)
        brush = QtGui.QBrush(QtGui.QColor(117, 123, 157))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Inactive, QtGui.QPalette.Window, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.WindowText, brush)
        brush = QtGui.QBrush(QtGui.QColor(117, 123, 157))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Button, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Text, brush)
        brush = QtGui.QBrush(QtGui.QColor(255, 255, 255))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.ButtonText, brush)
        brush = QtGui.QBrush(QtGui.QColor(117, 123, 157))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Base, brush)
        brush = QtGui.QBrush(QtGui.QColor(117, 123, 157))
        brush.setStyle(QtCore.Qt.SolidPattern)
        palette.setBrush(QtGui.QPalette.Disabled, QtGui.QPalette.Window, brush)
        self.browseRawData.setPalette(palette)
        font = QtGui.QFont()
        font.setFamily("Segoe UI Semibold")
        font.setPointSize(9)
        font.setBold(True)
        font.setItalic(False)
        font.setWeight(81)
        self.browseRawData.setFont(font)
        self.browseRawData.setStyleSheet("background-color: rgba(117, 123, 157, 1);\n"
"color: rgb(255, 255, 255);\n"
"font: 650 9pt \"Segoe UI Semibold\";\n"
"border-radius:1.5px;\n"
"border-style:solid;\n"
"border-bottom-width:4px;\n"
"border-right-widt:3px;\n"
"border-right-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:1,  stop:0 rgba(117, 123, 157,1), stop:1 rgba(217, 221, 244, 1));\n"
"border-bottom-color: qlineargradient(spread:pad, x1:0.301136, y1:0.034, x2:0.301, y2:1, stop:0 rgba(117, 123, 157, 1), stop:1 rgba(217, 221, 244, 1));\n"
"")
        self.browseRawData.setCheckable(False)
        self.browseRawData.setAutoRepeat(False)
        self.browseRawData.setAutoDefault(False)
        self.browseRawData.setDefault(True)
        self.browseRawData.setFlat(False)
        self.browseRawData.setObjectName("browseRawData")
        self.tableViewPreparation.raise_()
        self.PathLinePrepare.raise_()
        self.textPreparation.raise_()
        self.tabPreparation.addTab(self.tab, "")
        self.tab_4 = QtWidgets.QWidget()
        self.tab_4.setObjectName("tab_4")
        self.AnalyzeText = QtWidgets.QTextBrowser(self.tab_4)
        self.AnalyzeText.setGeometry(QtCore.QRect(230, 430, 731, 101))
        self.AnalyzeText.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-radius:5px;")
        self.AnalyzeText.setObjectName("AnalyzeText")
        self.AnalyzeView = QtWidgets.QLabel(self.tab_4)
        self.AnalyzeView.setGeometry(QtCore.QRect(30, 30, 931, 391))
        self.AnalyzeView.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-radius:5px;\n"
"")
        self.AnalyzeView.setText("")
        self.AnalyzeView.setObjectName("AnalyzeView")
        self.comboBox = QtWidgets.QComboBox(self.tab_4)
        self.comboBox.setGeometry(QtCore.QRect(260, 270, 121, 22))
        self.comboBox.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-radius:1px;\n"
"border-style:solid;\n"
"border-top-width:1px;\n"
"border-bottom-width:1px;\n"
"border-right-width:1px;\n"
"border-left-width:1px;")
        self.comboBox.setEditable(True)
        self.comboBox.setObjectName("comboBox")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.comboBox.addItem("")
        self.splitter_3 = QtWidgets.QSplitter(self.tab_4)
        self.splitter_3.setGeometry(QtCore.QRect(20, 430, 131, 41))
        self.splitter_3.setOrientation(QtCore.Qt.Horizontal)
        self.splitter_3.setObjectName("splitter_3")
        self.browseVizButton = QtWidgets.QPushButton(self.splitter_3)
        font = QtGui.QFont()
        font.setFamily("Segoe UI Semibold")
        font.setPointSize(9)
        font.setBold(True)
        font.setItalic(False)
        font.setWeight(81)
        self.browseVizButton.setFont(font)
        self.browseVizButton.setStyleSheet("background-color: rgba(117, 123, 157, 1);\n"
"color: rgb(255, 255, 255);\n"
"font: 650 9pt \"Segoe UI Semibold\";\n"
"border-radius:1.5px;\n"
"border-style:solid;\n"
"border-bottom-width:4px;\n"
"border-right-widt:3px;\n"
"border-right-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:1,  stop:0 rgba(117, 123, 157,1), stop:1 rgba(217, 221, 244, 1));\n"
"border-bottom-color: qlineargradient(spread:pad, x1:0.301136, y1:0.034, x2:0.301, y2:1, stop:0 rgba(117, 123, 157, 1), stop:1 rgba(217, 221, 244, 1));\n"
"")
        self.browseVizButton.setDefault(False)
        self.browseVizButton.setFlat(False)
        self.browseVizButton.setObjectName("browseVizButton")
        self.GenerateVizButton = QtWidgets.QPushButton(self.splitter_3)
        font = QtGui.QFont()
        font.setFamily("Segoe UI Semibold")
        font.setPointSize(9)
        font.setBold(True)
        font.setItalic(False)
        font.setWeight(81)
        self.GenerateVizButton.setFont(font)
        self.GenerateVizButton.setStyleSheet("background-color: rgba(117, 123, 157, 1);\n"
"color: rgb(255, 255, 255);\n"
"font: 650 9pt \"Segoe UI Semibold\";\n"
"border-radius:1.5px;\n"
"border-style:solid;\n"
"border-bottom-width:4px;\n"
"border-right-widt:3px;\n"
"border-right-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:1,  stop:0 rgba(117, 123, 157,1), stop:1 rgba(217, 221, 244, 1));\n"
"border-bottom-color: qlineargradient(spread:pad, x1:0.301136, y1:0.034, x2:0.301, y2:1, stop:0 rgba(117, 123, 157, 1), stop:1 rgba(217, 221, 244, 1));\n"
"")
        self.GenerateVizButton.setObjectName("GenerateVizButton")
        self.tabPreparation.addTab(self.tab_4, "")
        self.tab_2 = QtWidgets.QWidget()
        self.tab_2.setObjectName("tab_2")
        self.EvalText = QtWidgets.QTextBrowser(self.tab_2)
        self.EvalText.setGeometry(QtCore.QRect(660, 320, 321, 61))
        self.EvalText.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 8pt \"NewsGoth BT\";\n"
"border-radius:5px;")
        self.EvalText.setObjectName("EvalText")
        self.EvalView = QtWidgets.QLabel(self.tab_2)
        self.EvalView.setGeometry(QtCore.QRect(660, 50, 321, 261))
        self.EvalView.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 8pt \"NewsGoth BT\";\n"
"border-radius:5px;")
        self.EvalView.setText("")
        self.EvalView.setObjectName("EvalView")
        self.tableViewEval = QtWidgets.QTableView(self.tab_2)
        self.tableViewEval.setGeometry(QtCore.QRect(30, 50, 601, 461))
        self.tableViewEval.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 8pt \"NewsGoth BT\";\n"
"border-radius:5px;")
        self.tableViewEval.setObjectName("tableViewEval")
        self.splitter = QtWidgets.QSplitter(self.tab_2)
        self.splitter.setGeometry(QtCore.QRect(660, 484, 331, 23))
        self.splitter.setOrientation(QtCore.Qt.Horizontal)
        self.splitter.setObjectName("splitter")
        self.DisplayDataTrainButton = QtWidgets.QPushButton(self.splitter)
        self.DisplayDataTrainButton.setStyleSheet("background-color: rgba(117, 123, 157, 1);\n"
"color: rgb(255, 255, 255);\n"
"font: 650 9pt \"Segoe UI Semibold\";\n"
"border-radius:1.5px;\n"
"border-style:solid;\n"
"border-bottom-width:4px;\n"
"border-right-widt:3px;\n"
"border-right-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:1,  stop:0 rgba(117, 123, 157,1), stop:1 rgba(217, 221, 244, 1));\n"
"border-bottom-color: qlineargradient(spread:pad, x1:0.301136, y1:0.034, x2:0.301, y2:1, stop:0 rgba(117, 123, 157, 1), stop:1 rgba(217, 221, 244, 1));\n"
"")
        self.DisplayDataTrainButton.setObjectName("DisplayDataTrainButton")
        self.TestWithPredictionButton = QtWidgets.QPushButton(self.splitter)
        self.TestWithPredictionButton.setStyleSheet("background-color: rgba(117, 123, 157, 1);\n"
"color: rgb(255, 255, 255);\n"
"font: 650 9pt \"Segoe UI Semibold\";\n"
"border-radius:1.5px;\n"
"border-style:solid;\n"
"border-bottom-width:4px;\n"
"border-right-widt:3px;\n"
"border-right-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:1,  stop:0 rgba(117, 123, 157,1), stop:1 rgba(217, 221, 244, 1));\n"
"border-bottom-color: qlineargradient(spread:pad, x1:0.301136, y1:0.034, x2:0.301, y2:1, stop:0 rgba(117, 123, 157, 1), stop:1 rgba(217, 221, 244, 1));\n"
"")
        self.TestWithPredictionButton.setObjectName("TestWithPredictionButton")
        self.label_8 = QtWidgets.QLabel(self.tab_2)
        self.label_8.setGeometry(QtCore.QRect(661, 450, 53, 16))
        self.label_8.setObjectName("label_8")
        self.InputTest = QtWidgets.QLineEdit(self.tab_2)
        self.InputTest.setGeometry(QtCore.QRect(870, 424, 71, 20))
        self.InputTest.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-radius:5px;")
        self.InputTest.setObjectName("InputTest")
        self.BrowseFileEval = QtWidgets.QPushButton(self.tab_2)
        self.BrowseFileEval.setGeometry(QtCore.QRect(661, 395, 321, 23))
        self.BrowseFileEval.setStyleSheet("background-color: rgba(117, 123, 157, 1);\n"
"color: rgb(255, 255, 255);\n"
"font: 650 9pt \"Segoe UI Semibold\";\n"
"border-radius:1.5px;\n"
"border-style:solid;\n"
"border-bottom-width:4px;\n"
"border-right-widt:3px;\n"
"border-right-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:1,  stop:0 rgba(117, 123, 157,1), stop:1 rgba(217, 221, 244, 1));\n"
"border-bottom-color: qlineargradient(spread:pad, x1:0.301136, y1:0.034, x2:0.301, y2:1, stop:0 rgba(117, 123, 157, 1), stop:1 rgba(217, 221, 244, 1));\n"
"")
        self.BrowseFileEval.setObjectName("BrowseFileEval")
        self.EvaluationButton = QtWidgets.QPushButton(self.tab_2)
        self.EvaluationButton.setGeometry(QtCore.QRect(870, 450, 81, 23))
        self.EvaluationButton.setStyleSheet("background-color: rgba(117, 123, 157, 1);\n"
"color: rgb(255, 255, 255);\n"
"font: 650 9pt \"Segoe UI Semibold\";\n"
"border-radius:1.5px;\n"
"border-style:solid;\n"
"border-bottom-width:4px;\n"
"border-right-widt:3px;\n"
"border-right-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:1,  stop:0 rgba(117, 123, 157,1), stop:1 rgba(217, 221, 244, 1));\n"
"border-bottom-color: qlineargradient(spread:pad, x1:0.301136, y1:0.034, x2:0.301, y2:1, stop:0 rgba(117, 123, 157, 1), stop:1 rgba(217, 221, 244, 1));\n"
"")
        self.EvaluationButton.setObjectName("EvaluationButton")
        self.InputN = QtWidgets.QLineEdit(self.tab_2)
        self.InputN.setGeometry(QtCore.QRect(742, 451, 122, 20))
        self.InputN.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-radius:5px;")
        self.InputN.setObjectName("InputN")
        self.label_7 = QtWidgets.QLabel(self.tab_2)
        self.label_7.setGeometry(QtCore.QRect(820, 440, 24, 16))
        self.label_7.setObjectName("label_7")
        self.label_6 = QtWidgets.QLabel(self.tab_2)
        self.label_6.setGeometry(QtCore.QRect(950, 424, 21, 16))
        self.label_6.setObjectName("label_6")
        self.InputTrain = QtWidgets.QLineEdit(self.tab_2)
        self.InputTrain.setGeometry(QtCore.QRect(742, 424, 71, 20))
        self.InputTrain.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-radius:5px;")
        self.InputTrain.setObjectName("InputTrain")
        self.label_5 = QtWidgets.QLabel(self.tab_2)
        self.label_5.setGeometry(QtCore.QRect(661, 424, 48, 16))
        self.label_5.setObjectName("label_5")
        self.label_2 = QtWidgets.QLabel(self.tab_2)
        self.label_2.setGeometry(QtCore.QRect(100, 10, 81, 20))
        self.label_2.setObjectName("label_2")
        self.PathLineEval = QtWidgets.QLineEdit(self.tab_2)
        self.PathLineEval.setGeometry(QtCore.QRect(190, 10, 321, 20))
        self.PathLineEval.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-radius:5px;")
        self.PathLineEval.setObjectName("PathLineEval")
        self.tabPreparation.addTab(self.tab_2, "")
        self.tab_3 = QtWidgets.QWidget()
        self.tab_3.setObjectName("tab_3")
        self.tableViewPredict = QtWidgets.QTableView(self.tab_3)
        self.tableViewPredict.setGeometry(QtCore.QRect(10, 60, 971, 411))
        self.tableViewPredict.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 8pt \"NewsGoth BT\";\n"
"border-radius:5px;")
        self.tableViewPredict.setObjectName("tableViewPredict")
        self.splitter_2 = QtWidgets.QSplitter(self.tab_3)
        self.splitter_2.setGeometry(QtCore.QRect(10, 490, 331, 41))
        self.splitter_2.setOrientation(QtCore.Qt.Horizontal)
        self.splitter_2.setObjectName("splitter_2")
        self.BrowseFilePredictButton = QtWidgets.QPushButton(self.splitter_2)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.BrowseFilePredictButton.setFont(font)
        self.BrowseFilePredictButton.setObjectName("BrowseFilePredictButton")
        self.PredictButton = QtWidgets.QPushButton(self.splitter_2)
        font = QtGui.QFont()
        font.setPointSize(10)
        self.PredictButton.setFont(font)
        self.PredictButton.setObjectName("PredictButton")
        self.label_3 = QtWidgets.QLabel(self.tab_3)
        self.label_3.setGeometry(QtCore.QRect(290, 20, 41, 16))
        self.label_3.setObjectName("label_3")
        self.PathLinePredict = QtWidgets.QLineEdit(self.tab_3)
        self.PathLinePredict.setGeometry(QtCore.QRect(350, 20, 321, 20))
        self.PathLinePredict.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"border-radius:5px;")
        self.PathLinePredict.setObjectName("PathLinePredict")
        self.tabPreparation.addTab(self.tab_3, "")

        self.retranslateUi(Form)
        self.tabPreparation.setCurrentIndex(0)
        QtCore.QMetaObject.connectSlotsByName(Form)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.CheckDataButton.setText(_translate("Form", "Check Data"))
        self.PreparationButton.setText(_translate("Form", "Data Preparation"))
        self.browseRawData.setText(_translate("Form", "Browse Raw Data"))
        self.tabPreparation.setTabText(self.tabPreparation.indexOf(self.tab), _translate("Form", "Prepare Data"))
        self.comboBox.setItemText(0, _translate("Form", "Scatter Plot"))
        self.comboBox.setItemText(1, _translate("Form", "Count Airline"))
        self.comboBox.setItemText(2, _translate("Form", "Count Aircraft"))
        self.comboBox.setItemText(3, _translate("Form", "Airline By All"))
        self.comboBox.setItemText(4, _translate("Form", "Aircraft By All"))
        self.comboBox.setItemText(5, _translate("Form", "Percentage Airline"))
        self.comboBox.setItemText(6, _translate("Form", "Percentage Aircraft"))
        self.browseVizButton.setText(_translate("Form", "Browse File"))
        self.GenerateVizButton.setText(_translate("Form", "Visualize"))
        self.tabPreparation.setTabText(self.tabPreparation.indexOf(self.tab_4), _translate("Form", "Visualize Data"))
        self.DisplayDataTrainButton.setText(_translate("Form", "Train"))
        self.TestWithPredictionButton.setText(_translate("Form", "Test Prediction"))
        self.label_8.setText(_translate("Form", "Neightbour"))
        self.BrowseFileEval.setText(_translate("Form", "Browse Data"))
        self.EvaluationButton.setText(_translate("Form", "Evaluate Model"))
        self.label_7.setText(_translate("Form", "Train"))
        self.label_6.setText(_translate("Form", "Test"))
        self.label_5.setText(_translate("Form", "Rasio (%)"))
        self.label_2.setText(_translate("Form", "Dataset Path :"))
        self.tabPreparation.setTabText(self.tabPreparation.indexOf(self.tab_2), _translate("Form", "Model Evaluation"))
        self.BrowseFilePredictButton.setText(_translate("Form", "Browse Data"))
        self.PredictButton.setText(_translate("Form", "Predict"))
        self.label_3.setText(_translate("Form", " Path :"))
        self.tabPreparation.setTabText(self.tabPreparation.indexOf(self.tab_3), _translate("Form", "Predict Data"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\HP\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3441: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
